# %%
import pandas as pd
df = pd.read_csv('ww2_dataset2.csv')
import numpy as np

# %%
df.head()
# Out:
#      Country Total pop 19391939 Militarydeaths Civilian deaths Totaldeaths  \
# 0  Australia          6,968,000         39,700             700       40400
# 1    Belgium          8,387,000         12,000          76,000       88000
# 2   Bulgaria          6,458,000         18,500           3,000       21500
# 3     Canada         11,267,000         42,000           1,600       43600
# 4     France         41,680,000        210,000         390,000      600000
#
#    % of Population Militarywounded
# 0             0.58          39,803
# 1             1.05          55,513
# 2             0.33          21,878
# 3             0.38          53,174
# 4             1.44         390,000

# %%
WW2 = df

# %%
print(WW2)
# Out:
#            Country Total pop 19391939 Militarydeaths Civilian deaths  \
# 0        Australia          6,968,000         39,700             700
# 1          Belgium          8,387,000         12,000          76,000
# 2         Bulgaria          6,458,000         18,500           3,000
# 3           Canada         11,267,000         42,000           1,600
# 4           France         41,680,000        210,000         390,000
# 5          Germany         69,300,000      5,318,000       3,000,000
# 6           Greece          7,222,000         35,100         171,800
# 7          Hungary          9,129,000        200,000         664,000
# 8            India        377,800,000         87,000             NaN
# 9            Italy         44,394,000        341,000         153,200
# 10           Japan         71,380,000      2,300,000         800,000
# 11    Newfoundland            320,000          1,100             100
# 12     New Zealand          1,629,000         11,700             NaN
# 13         Romania         15,970,000        300,000         200,000
# 14    South Africa         10,160,000         11,900             NaN
# 15    Soviet Union        188,793,000     11,400,000      10,000,000
# 16          Sweden          6,341,000            100           2,000
# 17     Switzerland          4,210,000            NaN             100
# 18        Thailand         15,023,000          5,600           2,000
# 19          Turkey         17,370,000            200             NaN
# 20  United Kingdom         47,760,000        383,700          67,200
# 21   United States        131,028,000        407,300          12,100
#
#    Totaldeaths  % of Population Militarywounded
# 0        40400            0.580          39,803
# 1        88000            1.050          55,513
# 2        21500            0.330          21,878
# 3        43600            0.380          53,174
# 4       600000            1.440         390,000
# 5    7,400,000            1.000       7,300,000
# 6      507,000            9.095          47,290
# 7      864,000            7.270          89,313
# 8    3,087,000            0.580          64,354
# 9      492,400            1.135         320,000
# 10   3,100,000            3.920         326,000
# 11        1200            0.300             NaN
# 12       11700            0.720          19,314
# 13     500,000            3.130         332,769
# 14       11900            0.120          14,363
# 15  27,000,000            1.150             NaN
# 16        2100            0.030             NaN
# 17         100            0.000             NaN
# 18        7600            0.050             NaN
# 19         200            0.000             NaN
# 20      450900            0.940         376,239
# 21      419400            0.320         671,801

# %%
df['Country']
# Out:
# 0          Australia
# 1            Belgium
# 2           Bulgaria
# 3             Canada
# 4             France
# 5            Germany
# 6             Greece
# 7            Hungary
# 8              India
# 9              Italy
# 10             Japan
# 11      Newfoundland
# 12       New Zealand
# 13           Romania
# 14      South Africa
# 15      Soviet Union
# 16            Sweden
# 17       Switzerland
# 18          Thailand
# 19            Turkey
# 20    United Kingdom
# 21     United States
# Name: Country, dtype: object

# %%
 -m"
# Out:
#   Input In [7]
#     -m"
#        ^
# SyntaxError: EOL while scanning string literal

# %%
WW2 = WW2.replace(',','', regex=True)

# %%
WW2 = WW2.drop(labels=[11,18,16,19,17], axis=0)

# %%
print(WW2)
# Out:
#            Country Total pop 19391939 Militarydeaths Civilian deaths  \
# 0        Australia            6968000          39700             700
# 1          Belgium            8387000          12000           76000
# 2         Bulgaria            6458000          18500            3000
# 3           Canada           11267000          42000            1600
# 4           France           41680000         210000          390000
# 5          Germany           69300000        5318000         3000000
# 6           Greece            7222000          35100          171800
# 7          Hungary            9129000         200000          664000
# 8            India          377800000          87000             NaN
# 9            Italy           44394000         341000          153200
# 10           Japan           71380000        2300000          800000
# 12     New Zealand            1629000          11700             NaN
# 13         Romania           15970000         300000          200000
# 14    South Africa           10160000          11900             NaN
# 15    Soviet Union          188793000       11400000        10000000
# 20  United Kingdom           47760000         383700           67200
# 21   United States          131028000         407300           12100
#
#    Totaldeaths  % of Population Militarywounded
# 0        40400            0.580           39803
# 1        88000            1.050           55513
# 2        21500            0.330           21878
# 3        43600            0.380           53174
# 4       600000            1.440          390000
# 5      7400000            1.000         7300000
# 6       507000            9.095           47290
# 7       864000            7.270           89313
# 8      3087000            0.580           64354
# 9       492400            1.135          320000
# 10     3100000            3.920          326000
# 12       11700            0.720           19314
# 13      500000            3.130          332769
# 14       11900            0.120           14363
# 15    27000000            1.150             NaN
# 20      450900            0.940          376239
# 21      419400            0.320          671801

# %%
WW2.drop(['Militarywounded'], axis=1)
# Out:
#            Country Total pop 19391939 Militarydeaths Civilian deaths  \
# 0        Australia            6968000          39700             700
# 1          Belgium            8387000          12000           76000
# 2         Bulgaria            6458000          18500            3000
# 3           Canada           11267000          42000            1600
# 4           France           41680000         210000          390000
# 5          Germany           69300000        5318000         3000000
# 6           Greece            7222000          35100          171800
# 7          Hungary            9129000         200000          664000
# 8            India          377800000          87000             NaN
# 9            Italy           44394000         341000          153200
# 10           Japan           71380000        2300000          800000
# 12     New Zealand            1629000          11700             NaN
# 13         Romania           15970000         300000          200000
# 14    South Africa           10160000          11900             NaN
# 15    Soviet Union          188793000       11400000        10000000
# 20  United Kingdom           47760000         383700           67200
# 21   United States          131028000         407300           12100
#
#    Totaldeaths  % of Population
# 0        40400            0.580
# 1        88000            1.050
# 2        21500            0.330
# 3        43600            0.380
# 4       600000            1.440
# 5      7400000            1.000
# 6       507000            9.095
# 7       864000            7.270
# 8      3087000            0.580
# 9       492400            1.135
# 10     3100000            3.920
# 12       11700            0.720
# 13      500000            3.130
# 14       11900            0.120
# 15    27000000            1.150
# 20      450900            0.940
# 21      419400            0.320

# %%
WW2 = WW2.sort_values(by='% of Population',ascending=False)
WW2.head(21)
# Out:
#            Country Total pop 19391939 Militarydeaths Civilian deaths  \
# 6           Greece            7222000          35100          171800
# 7          Hungary            9129000         200000          664000
# 10           Japan           71380000        2300000          800000
# 13         Romania           15970000         300000          200000
# 4           France           41680000         210000          390000
# 15    Soviet Union          188793000       11400000        10000000
# 9            Italy           44394000         341000          153200
# 1          Belgium            8387000          12000           76000
# 5          Germany           69300000        5318000         3000000
# 20  United Kingdom           47760000         383700           67200
# 12     New Zealand            1629000          11700             NaN
# 0        Australia            6968000          39700             700
# 8            India          377800000          87000             NaN
# 3           Canada           11267000          42000            1600
# 2         Bulgaria            6458000          18500            3000
# 21   United States          131028000         407300           12100
# 14    South Africa           10160000          11900             NaN
#
#    Totaldeaths  % of Population Militarywounded
# 6       507000            9.095           47290
# 7       864000            7.270           89313
# 10     3100000            3.920          326000
# 13      500000            3.130          332769
# 4       600000            1.440          390000
# 15    27000000            1.150             NaN
# 9       492400            1.135          320000
# 1        88000            1.050           55513
# 5      7400000            1.000         7300000
# 20      450900            0.940          376239
# 12       11700            0.720           19314
# 0        40400            0.580           39803
# 8      3087000            0.580           64354
# 3        43600            0.380           53174
# 2        21500            0.330           21878
# 21      419400            0.320          671801
# 14       11900            0.120           14363

# %%
WW2.head()
# Out:
#     Country Total pop 19391939 Militarydeaths Civilian deaths Totaldeaths  \
# 6    Greece            7222000          35100          171800      507000
# 7   Hungary            9129000         200000          664000      864000
# 10    Japan           71380000        2300000          800000     3100000
# 13  Romania           15970000         300000          200000      500000
# 4    France           41680000         210000          390000      600000
#
#     % of Population Militarywounded
# 6             9.095           47290
# 7             7.270           89313
# 10            3.920          326000
# 13            3.130          332769
# 4             1.440          390000

# %%
print(WW2)
# Out:
#            Country Total pop 19391939 Militarydeaths Civilian deaths  \
# 6           Greece            7222000          35100          171800
# 7          Hungary            9129000         200000          664000
# 10           Japan           71380000        2300000          800000
# 13         Romania           15970000         300000          200000
# 4           France           41680000         210000          390000
# 15    Soviet Union          188793000       11400000        10000000
# 9            Italy           44394000         341000          153200
# 1          Belgium            8387000          12000           76000
# 5          Germany           69300000        5318000         3000000
# 20  United Kingdom           47760000         383700           67200
# 12     New Zealand            1629000          11700             NaN
# 0        Australia            6968000          39700             700
# 8            India          377800000          87000             NaN
# 3           Canada           11267000          42000            1600
# 2         Bulgaria            6458000          18500            3000
# 21   United States          131028000         407300           12100
# 14    South Africa           10160000          11900             NaN
#
#    Totaldeaths  % of Population Militarywounded
# 6       507000            9.095           47290
# 7       864000            7.270           89313
# 10     3100000            3.920          326000
# 13      500000            3.130          332769
# 4       600000            1.440          390000
# 15    27000000            1.150             NaN
# 9       492400            1.135          320000
# 1        88000            1.050           55513
# 5      7400000            1.000         7300000
# 20      450900            0.940          376239
# 12       11700            0.720           19314
# 0        40400            0.580           39803
# 8      3087000            0.580           64354
# 3        43600            0.380           53174
# 2        21500            0.330           21878
# 21      419400            0.320          671801
# 14       11900            0.120           14363

# %%
WW2 = WW2.astype({'Militarydeaths':'int'})

# %%
WW2 = WW2.astype({'Total pop 19391939':'int'})

# %%
WW2 = WW2.drop(labels=[12], axis=0)

# %%
print(WW2)
# Out:
#            Country  Total pop 19391939  Militarydeaths Civilian deaths  \
# 6           Greece             7222000           35100          171800
# 7          Hungary             9129000          200000          664000
# 10           Japan            71380000         2300000          800000
# 13         Romania            15970000          300000          200000
# 4           France            41680000          210000          390000
# 15    Soviet Union           188793000        11400000        10000000
# 9            Italy            44394000          341000          153200
# 1          Belgium             8387000           12000           76000
# 5          Germany            69300000         5318000         3000000
# 20  United Kingdom            47760000          383700           67200
# 0        Australia             6968000           39700             700
# 8            India           377800000           87000             NaN
# 3           Canada            11267000           42000            1600
# 2         Bulgaria             6458000           18500            3000
# 21   United States           131028000          407300           12100
# 14    South Africa            10160000           11900             NaN
#
#    Totaldeaths  % of Population Militarywounded
# 6       507000            9.095           47290
# 7       864000            7.270           89313
# 10     3100000            3.920          326000
# 13      500000            3.130          332769
# 4       600000            1.440          390000
# 15    27000000            1.150             NaN
# 9       492400            1.135          320000
# 1        88000            1.050           55513
# 5      7400000            1.000         7300000
# 20      450900            0.940          376239
# 0        40400            0.580           39803
# 8      3087000            0.580           64354
# 3        43600            0.380           53174
# 2        21500            0.330           21878
# 21      419400            0.320          671801
# 14       11900            0.120           14363

# %%
WW2 = WW2.astype({'Civilian deaths':'int'})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [44], in <cell line: 1>()
# ----> 1 WW2 = WW2.astype({'Civilian deaths':'int'})
#
# File ~\Anaconda3\lib\site-packages\pandas\core\generic.py:5898, in NDFrame.astype(self, dtype, copy, errors)
#    5896             res_col = col.copy() if copy else col
#    5897         else:
# -> 5898             res_col = col.astype(dtype=cdt, copy=copy, errors=errors)
#    5899         results.append(res_col)
#    5901 elif is_extension_array_dtype(dtype) and self.ndim > 1:
#    5902     # GH 18099/22869: columnwise conversion to extension dtype
#    5903     # GH 24704: use iloc to handle duplicate column names
#    5904     # TODO(EA2D): special case not needed with 2D EAs
#
# File ~\Anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
#     418 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py:304, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     302         applied = b.apply(f, **kwargs)
#     303     else:
# --> 304         applied = getattr(b, f)(**kwargs)
#     305 except (TypeError, NotImplementedError):
#     306     if not ignore_failures:
#
# File ~\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py:580, in Block.astype(self, dtype, copy, errors)
#     562 """
#     563 Coerce to the new dtype.
#     564
#    (...)
#     576 Block
#     577 """
#     578 values = self.values
# --> 580 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     582 new_values = maybe_coerce_values(new_values)
#     583 newb = self.make_block(new_values)
#
# File ~\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1292, in astype_array_safe(values, dtype, copy, errors)
#    1289     dtype = dtype.numpy_dtype
#    1291 try:
# -> 1292     new_values = astype_array(values, dtype, copy=copy)
#    1293 except (ValueError, TypeError):
#    1294     # e.g. astype_nansafe can fail on object-dtype of strings
#    1295     #  trying to convert to float
#    1296     if errors == "ignore":
#
# File ~\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1237, in astype_array(values, dtype, copy)
#    1234     values = values.astype(dtype, copy=copy)
#    1236 else:
# -> 1237     values = astype_nansafe(values, dtype, copy=copy)
#    1239 # in pandas we don't store numpy str dtypes, so convert to object
#    1240 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1154, in astype_nansafe(arr, dtype, copy, skipna)
#    1150 elif is_object_dtype(arr.dtype):
#    1151
#    1152     # work around NumPy brokenness, #1987
#    1153     if np.issubdtype(dtype.type, np.integer):
# -> 1154         return lib.astype_intsafe(arr, dtype)
#    1156     # if we have a datetime/timedelta array of objects
#    1157     # then coerce to a proper dtype and recall astype_nansafe
#    1159     elif is_datetime64_dtype(dtype):
#
# File ~\Anaconda3\lib\site-packages\pandas\_libs\lib.pyx:668, in pandas._libs.lib.astype_intsafe()
#
# ValueError: cannot convert float NaN to integer

# %%
print(WW2)
# Out:
#            Country  Total pop 19391939  Militarydeaths Civilian deaths  \
# 6           Greece             7222000           35100          171800
# 7          Hungary             9129000          200000          664000
# 10           Japan            71380000         2300000          800000
# 13         Romania            15970000          300000          200000
# 4           France            41680000          210000          390000
# 15    Soviet Union           188793000        11400000        10000000
# 9            Italy            44394000          341000          153200
# 1          Belgium             8387000           12000           76000
# 5          Germany            69300000         5318000         3000000
# 20  United Kingdom            47760000          383700           67200
# 0        Australia             6968000           39700             700
# 8            India           377800000           87000             NaN
# 3           Canada            11267000           42000            1600
# 2         Bulgaria             6458000           18500            3000
# 21   United States           131028000          407300           12100
# 14    South Africa            10160000           11900             NaN
#
#    Totaldeaths  % of Population Militarywounded
# 6       507000            9.095           47290
# 7       864000            7.270           89313
# 10     3100000            3.920          326000
# 13      500000            3.130          332769
# 4       600000            1.440          390000
# 15    27000000            1.150             NaN
# 9       492400            1.135          320000
# 1        88000            1.050           55513
# 5      7400000            1.000         7300000
# 20      450900            0.940          376239
# 0        40400            0.580           39803
# 8      3087000            0.580           64354
# 3        43600            0.380           53174
# 2        21500            0.330           21878
# 21      419400            0.320          671801
# 14       11900            0.120           14363

# %%
WW2 = WW2.drop(labels=[6,7,13,1,3,2], axis=0)

# %%
print(WW2)
# Out:
#            Country  Total pop 19391939  Militarydeaths Civilian deaths  \
# 10           Japan            71380000         2300000          800000
# 4           France            41680000          210000          390000
# 15    Soviet Union           188793000        11400000        10000000
# 9            Italy            44394000          341000          153200
# 5          Germany            69300000         5318000         3000000
# 20  United Kingdom            47760000          383700           67200
# 0        Australia             6968000           39700             700
# 8            India           377800000           87000             NaN
# 21   United States           131028000          407300           12100
# 14    South Africa            10160000           11900             NaN
#
#    Totaldeaths  % of Population Militarywounded
# 10     3100000            3.920          326000
# 4       600000            1.440          390000
# 15    27000000            1.150             NaN
# 9       492400            1.135          320000
# 5      7400000            1.000         7300000
# 20      450900            0.940          376239
# 0        40400            0.580           39803
# 8      3087000            0.580           64354
# 21      419400            0.320          671801
# 14       11900            0.120           14363

# %%
WW2.drop_duplicates(subset=['Country'], keep=False)
# Out:
#            Country  Total pop 19391939  Militarydeaths Civilian deaths  \
# 10           Japan            71380000         2300000          800000
# 4           France            41680000          210000          390000
# 15    Soviet Union           188793000        11400000        10000000
# 9            Italy            44394000          341000          153200
# 5          Germany            69300000         5318000         3000000
# 20  United Kingdom            47760000          383700           67200
# 0        Australia             6968000           39700             700
# 8            India           377800000           87000             NaN
# 21   United States           131028000          407300           12100
# 14    South Africa            10160000           11900             NaN
#
#    Totaldeaths  % of Population Militarywounded
# 10     3100000            3.920          326000
# 4       600000            1.440          390000
# 15    27000000            1.150             NaN
# 9       492400            1.135          320000
# 5      7400000            1.000         7300000
# 20      450900            0.940          376239
# 0        40400            0.580           39803
# 8      3087000            0.580           64354
# 21      419400            0.320          671801
# 14       11900            0.120           14363

# %%
import requests
from bs4 import BeautifulSoup

url = "https://en.wikipedia.org/wiki/World_War_I_casualties"
page = requests.get(url)

soup = BeautifulSoup(page.content, 'html.parser')
indiatable=soup.find('table',{'class':"wikitable"})

import pandas as pd

# %%
listings = soup.find_all("li", class_="td")
for listing in listings:
        print("tables")

# %%
df=pd.read_html(str(indiatable))

# %%
df=pd.DataFrame(df[0])
print(df.head())
# Out:
#                                      Nation  \
#   Allies and co-belligerents of World War I
# 0                               Australia b
# 1                                  Canada d
# 2                                   India g
# 3                             New Zealand l
# 4                            Newfoundland m
#
#                       Population (millions)  \
#   Allies and co-belligerents of World War I
# 0                                       5.0
# 1                                       7.2
# 2                                     315.1
# 3                                       1.1
# 4                                       0.2
#
#   Combat deaths and missing in action (included in total military deaths)  \
#                                 Allies and co-belligerents of World War I
# 0                                         61,527[19]
# 1                                         56,638[22]
# 2                                         64,449[21]
# 3                                         18,166[25]
# 4                                          1,204[21]
#
#     Total military deaths (from all causes)  \
#   Allies and co-belligerents of World War I
# 0                   59,330[20]to 62,149[11]
# 1                  56,639[21] to 64,996[11]
# 2                  64,449[21] to 73,905[11]
# 3                  16,711[21] to 18,060[11]
# 4  1,204[21] to 1,570[26](included with UK)
#
#   Civilian deaths (military action and crimes against humanity)  \
#                       Allies and co-belligerents of World War I
# 0                                                NaN
# 1                                      1,963[23][24]
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Increase in civilian deaths (malnutrition and disease excluding Influenza pandemic)  \
#                                             Allies and co-belligerents of World War I
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                Total deaths  \
#   Allies and co-belligerents of World War I
# 0                           59,330to 62,149
# 1                          58,639 to 66,996
# 2                          64,449 to 73,905
# 3                          16,711 to 18,060
# 4                             1,204to 1,570
#
#                   Deaths as % of population  \
#   Allies and co-belligerents of World War I
# 0                              1.2% to 1.2%
# 1                              0.8% to 0.9%
# 2                                  0% to 0%
# 3                              1.5% to 1.6%
# 4                              0.6% to 0.8%
#
#                            Military wounded
#   Allies and co-belligerents of World War I
# 0                               152,171[21]
# 1                               149,732[21]
# 2                                69,214[21]
# 3                                41,317[21]
# 4                                 2,314[21]

# %%
WW1 = df

# %%
print(WW1)
# Out:
#                                       Nation  \
#    Allies and co-belligerents of World War I
# 0                                Australia b
# 1                                   Canada d
# 2                                    India g
# 3                              New Zealand l
# 4                             Newfoundland m
# 5                             South Africa r
# 6             United Kingdom(and Colonies) s
# 7               Sub-total for British Empire
# 8                                  Belgium c
# 9                                   France e
# 10                                  Greece f
# 11                                   Italy h
# 12                                   Japan i
# 13                              Montenegro k
# 14                                Portugal n
# 15                                 Romania o
# 16                                  Russia p
# 17                                  Serbia q
# 18                           United States t
# 19                        TotalAllied Powers
# 20                            Central Powers
# 21                         Austria-Hungary u
# 22                                Bulgaria v
# 23                                 Germany w
# 24                          Ottoman Empire x
# 25                       TotalCentral Powers
# 26                           Neutral nations
# 27                                 Denmark y
# 28                              Luxembourg j
# 29                                  Norway z
# 30                           Qajar Persia az
# 31                                 Sweden bz
# 32                               Grand total
#
#                        Population (millions)  \
#    Allies and co-belligerents of World War I
# 0                                        5.0
# 1                                        7.2
# 2                                      315.1
# 3                                        1.1
# 4                                        0.2
# 5                                        6.0
# 6                                       45.4
# 7                                      380.0
# 8                                        7.4
# 9                                       39.6
# 10                                       4.8
# 11                                      35.6
# 12                                      53.6
# 13                                       0.5
# 14                                       6.0
# 15                                       7.5
# 16                                     175.1
# 17                                       4.5
# 18                                      92.0
# 19                                     806.6
# 20                            Central Powers
# 21                                      51.4
# 22                                       4.5
# 23                                      64.9
# 24                                      21.3
# 25                                     142.1
# 26                           Neutral nations
# 27                                       2.8
# 28                                       0.3
# 29                                       2.4
# 30                                  10.5[75]
# 31                                       5.6
# 32                                     959.7
#
#    Combat deaths and missing in action (included in total military deaths)  \
#                                  Allies and co-belligerents of World War I
# 0                                          61,527[19]
# 1                                          56,638[22]
# 2                                          64,449[21]
# 3                                          18,166[25]
# 4                                           1,204[21]
# 5                                           7,121[21]
# 6                                           744,000s1
# 7                                              953104
# 8                                          38,170[20]
# 9                                   1,150,000[34][35]
# 10                                          5,000[20]
# 11                                        460,000[29]
# 12                                            300[33]
# 13                                          3,000[33]
# 14                                          7,222[29]
# 15                                        335,706[20]
# 16                       775,369 to 1,700,000[33][20]
# 17                                        127,500[20]
# 18                                         53,402[52]
# 19                                            4833404
# 20                                     Central Powers
# 21                                  1,016,200[56][57]
# 22                                         87,500[33]
# 23                              1,800,000[33][62][63]
# 24                                        305,085[70]
# 25                                            3208785
# 26                                    Neutral nations
# 27          See footnote re: Danes in German military
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                            8042189
#
#      Total military deaths (from all causes)  \
#    Allies and co-belligerents of World War I
# 0                    59,330[20]to 62,149[11]
# 1                   56,639[21] to 64,996[11]
# 2                   64,449[21] to 73,905[11]
# 3                   16,711[21] to 18,060[11]
# 4   1,204[21] to 1,570[26](included with UK)
# 5                     7,121[21] to 9,726[11]
# 6                                887,858[11]
# 7                       949,454 to 1,118,264
# 8                    38,170[29]to 58,637[30]
# 9              1,357,000[20]to 1,397,800[36]
# 10                   5,000[20] to 26,000[39]
# 11                460,000[29] to 651,000[41]
# 12                      300[33] to 4,661[44]
# 13                   3,000[33] to 13,325[44]
# 14                                 7,222[29]
# 15                250,000[44] to 335,706[20]
# 16             1,700,000[33] to2,254,369[48]
# 17                 300,000[50]to 450,000[51]
# 18                           116,708[53][54]
# 19                    5,186,854 to 6,433,692
# 20                            Central Powers
# 21         1,200,000[33][58]to 1,494,200[57]
# 22                            87,500[33][20]
# 23                         2,037,000[64][65]
# 24                325,000[33] to 771,844[71]
# 25                    3,386,200 to 4,390,544
# 26                           Neutral nations
# 27                                       NaN
# 28                                      2800
# 29                                       NaN
# 30                                       NaN
# 31                                       NaN
# 32                   8,573,054 to 10,824,236
#
#    Civilian deaths (military action and crimes against humanity)  \
#                        Allies and co-belligerents of World War I
# 0                                                 NaN
# 1                                       1,963[23][24]
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                      16,829[21][27]
# 7                                               18829
# 8                                          23,700[31]
# 9                                  40,000[18][37][38]
# 10                                                NaN
# 11                                          3,400[42]
# 12                                                NaN
# 13                                                NaN
# 14                                             13[45]
# 15                                        130,000[47]
# 16                                        410,000[49]
# 17                                                NaN
# 18                                            757[55]
# 19                                             626699
# 20                                     Central Powers
# 21                                        120,000[59]
# 22                                                NaN
# 23                                            720[66]
# 24                                      1,500,000[72]
# 25                                            1620720
# 26                                    Neutral nations
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                            2250099
#
#    Increase in civilian deaths (malnutrition and disease excluding Influenza pandemic)  \
#                                              Allies and co-belligerents of World War I
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                         107,000[28]
# 7                                              107000
# 8                                          62,000[32]
# 9                                         300,000[32]
# 10                                        150,000[40]
# 11                                        589,000[43]
# 12                                                NaN
# 13                                                NaN
# 14                                         82,000[46]
# 15                                        200,000[47]
# 16                                        730,000[49]
# 17                          450,000[50]to 800,000[51]
# 18                                                NaN
# 19                              3,420,000to 3,770,000
# 20                                     Central Powers
# 21                                        467,000[60]
# 22                                        100,000[61]
# 23                     424,000[67] to 763,000[68][69]
# 24                                      1,000,000[73]
# 25                             1,991,000 to 2,330,000
# 26                                    Neutral nations
# 27                                            700[74]
# 28                                                NaN
# 29                                          1,180[44]
# 30                                      2,000,000[76]
# 31                                            800[44]
# 32                             5,411,000 to 6,100,000
#
#                                 Total deaths  \
#    Allies and co-belligerents of World War I
# 0                            59,330to 62,149
# 1                           58,639 to 66,996
# 2                           64,449 to 73,905
# 3                           16,711 to 18,060
# 4                              1,204to 1,570
# 5                             7,121 to 9,726
# 6                       867,829 to 1,011,687
# 7                      1,077,283to 1,244,093
# 8                          123,870to 144,337
# 9                      1,697,000to 1,737,800
# 10                        155,000 to 176,000
# 11                    1,052,400 to 1,243,400
# 12                              300 to 4,661
# 13                           3,000 to 13,325
# 14                                     89235
# 15                        580,000 to 665,706
# 16                     2,840,000 to3,394,369
# 17                      750,000 to 1,250,000
# 18                                    117466
# 19                   9,235,553 to 10,080,391
# 20                            Central Powers
# 21                    1,787,000 to 2,081,200
# 22                                    187500
# 23                    2,198,420 to 2,800,720
# 24                    2,825,000 to 3,271,844
# 25                    6,997,920 to 8,341,264
# 26                           Neutral nations
# 27                                       700
# 28                                       NaN
# 29                                      1180
# 30                                   2000000
# 31                                       800
# 32               15,000,000 to 22,000,000[1]
#
#                    Deaths as % of population  \
#    Allies and co-belligerents of World War I
# 0                               1.2% to 1.2%
# 1                               0.8% to 0.9%
# 2                                   0% to 0%
# 3                               1.5% to 1.6%
# 4                               0.6% to 0.8%
# 5                               0.1% to 0.2%
# 6                               1.9% to 2.2%
# 7                               0.3% to 0.3%
# 8                                 1.7% to 2%
# 9                               4.3% to 4.4%
# 10                              3.2% to 3.7%
# 11                                3% to 3.5%
# 12                                  0% to 0%
# 13                              0.6% to 2.7%
# 14                                      1.5%
# 15                              7.7% to 8.9%
# 16                              1.6% to 1.9%
# 17                            16.7% to 27.8%
# 18                                      0.1%
# 19                              1.1% to 1.2%
# 20                            Central Powers
# 21                                3.5% to 4%
# 22                                      3.4%
# 23                              3.4% to 4.3%
# 24                            13.3% to 15.4%
# 25                              4.9% to 5.9%
# 26                           Neutral nations
# 27                                        0%
# 28                              See footnote
# 29                                      0.1%
# 30                                       19%
# 31                                        0%
# 32                              1.7% to 2.3%
#
#                             Military wounded
#    Allies and co-belligerents of World War I
# 0                                152,171[21]
# 1                                149,732[21]
# 2                                 69,214[21]
# 3                                 41,317[21]
# 4                                  2,314[21]
# 5                                 12,029[21]
# 6                                1,675,000s1
# 7                                    2101077
# 8                                 44,686[33]
# 9                              4,266,000[33]
# 10                                21,000[33]
# 11                               947,000[33]
# 12                                   907[33]
# 13                                10,000[33]
# 14                                13,751[29]
# 15                               120,000[33]
# 16             3,749,000[48] to4,950,000[33]
# 17                               133,148[33]
# 18                               204,002[53]
# 19                  11,611,271 to 12,812,271
# 20                            Central Powers
# 21                             3,620,000[21]
# 22                           152,390[33][20]
# 23                             4,215,662[64]
# 24                400,000[33] to 763,753[71]
# 25                     8,388,052to 8,751,805
# 26                           Neutral nations
# 27                                         —
# 28                                       NaN
# 29                                         —
# 30                                         —
# 31                                         —
# 32                  22,101,100 to 23,665,873

# %%
WW1 = WW1.drop(labels=[0,1,2,3,4,5,7,8,10,13,14,15,17,19,20,21,22,24,25,26,27,28,29,30,31,32], axis=0)

# %%
print(WW1)
# Out:
#                                       Nation  \
#    Allies and co-belligerents of World War I
# 6             United Kingdom(and Colonies) s
# 9                                   France e
# 11                                   Italy h
# 12                                   Japan i
# 16                                  Russia p
# 18                           United States t
# 23                                 Germany w
#
#                        Population (millions)  \
#    Allies and co-belligerents of World War I
# 6                                       45.4
# 9                                       39.6
# 11                                      35.6
# 12                                      53.6
# 16                                     175.1
# 18                                      92.0
# 23                                      64.9
#
#    Combat deaths and missing in action (included in total military deaths)  \
#                                  Allies and co-belligerents of World War I
# 6                                           744,000s1
# 9                                   1,150,000[34][35]
# 11                                        460,000[29]
# 12                                            300[33]
# 16                       775,369 to 1,700,000[33][20]
# 18                                         53,402[52]
# 23                              1,800,000[33][62][63]
#
#      Total military deaths (from all causes)  \
#    Allies and co-belligerents of World War I
# 6                                887,858[11]
# 9              1,357,000[20]to 1,397,800[36]
# 11                460,000[29] to 651,000[41]
# 12                      300[33] to 4,661[44]
# 16             1,700,000[33] to2,254,369[48]
# 18                           116,708[53][54]
# 23                         2,037,000[64][65]
#
#    Civilian deaths (military action and crimes against humanity)  \
#                        Allies and co-belligerents of World War I
# 6                                      16,829[21][27]
# 9                                  40,000[18][37][38]
# 11                                          3,400[42]
# 12                                                NaN
# 16                                        410,000[49]
# 18                                            757[55]
# 23                                            720[66]
#
#    Increase in civilian deaths (malnutrition and disease excluding Influenza pandemic)  \
#                                              Allies and co-belligerents of World War I
# 6                                         107,000[28]
# 9                                         300,000[32]
# 11                                        589,000[43]
# 12                                                NaN
# 16                                        730,000[49]
# 18                                                NaN
# 23                     424,000[67] to 763,000[68][69]
#
#                                 Total deaths  \
#    Allies and co-belligerents of World War I
# 6                       867,829 to 1,011,687
# 9                      1,697,000to 1,737,800
# 11                    1,052,400 to 1,243,400
# 12                              300 to 4,661
# 16                     2,840,000 to3,394,369
# 18                                    117466
# 23                    2,198,420 to 2,800,720
#
#                    Deaths as % of population  \
#    Allies and co-belligerents of World War I
# 6                               1.9% to 2.2%
# 9                               4.3% to 4.4%
# 11                                3% to 3.5%
# 12                                  0% to 0%
# 16                              1.6% to 1.9%
# 18                                      0.1%
# 23                              3.4% to 4.3%
#
#                             Military wounded
#    Allies and co-belligerents of World War I
# 6                                1,675,000s1
# 9                              4,266,000[33]
# 11                               947,000[33]
# 12                                   907[33]
# 16             3,749,000[48] to4,950,000[33]
# 18                               204,002[53]
# 23                             4,215,662[64]

# %%
WW1 = WW1.rename(columns={'Population (millions)': 'Population', 'Nation': 'Country'})

# %%
WW1 = WW1.rename(columns={'Combat deaths and missing in action (included in total military deaths': 'Militarydeaths', 'Civilian deaths (military action and crimes against humanity': 'Civilian deaths'})

# %%
WW1 = WW1.rename(columns={'Total deaths': '	Totaldeaths', 'Deaths as % of population': '% of Population'})

# %%
print(WW1)
# Out:
#                                      Country  \
#    Allies and co-belligerents of World War I
# 6             United Kingdom(and Colonies) s
# 9                                   France e
# 11                                   Italy h
# 12                                   Japan i
# 16                                  Russia p
# 18                           United States t
# 23                                 Germany w
#
#                                   Population  \
#    Allies and co-belligerents of World War I
# 6                                       45.4
# 9                                       39.6
# 11                                      35.6
# 12                                      53.6
# 16                                     175.1
# 18                                      92.0
# 23                                      64.9
#
#    Combat deaths and missing in action (included in total military deaths)  \
#                                  Allies and co-belligerents of World War I
# 6                                           744,000s1
# 9                                   1,150,000[34][35]
# 11                                        460,000[29]
# 12                                            300[33]
# 16                       775,369 to 1,700,000[33][20]
# 18                                         53,402[52]
# 23                              1,800,000[33][62][63]
#
#      Total military deaths (from all causes)  \
#    Allies and co-belligerents of World War I
# 6                                887,858[11]
# 9              1,357,000[20]to 1,397,800[36]
# 11                460,000[29] to 651,000[41]
# 12                      300[33] to 4,661[44]
# 16             1,700,000[33] to2,254,369[48]
# 18                           116,708[53][54]
# 23                         2,037,000[64][65]
#
#    Civilian deaths (military action and crimes against humanity)  \
#                        Allies and co-belligerents of World War I
# 6                                      16,829[21][27]
# 9                                  40,000[18][37][38]
# 11                                          3,400[42]
# 12                                                NaN
# 16                                        410,000[49]
# 18                                            757[55]
# 23                                            720[66]
#
#    Increase in civilian deaths (malnutrition and disease excluding Influenza pandemic)  \
#                                              Allies and co-belligerents of World War I
# 6                                         107,000[28]
# 9                                         300,000[32]
# 11                                        589,000[43]
# 12                                                NaN
# 16                                        730,000[49]
# 18                                                NaN
# 23                     424,000[67] to 763,000[68][69]
#
#                                \tTotaldeaths  \
#    Allies and co-belligerents of World War I
# 6                       867,829 to 1,011,687
# 9                      1,697,000to 1,737,800
# 11                    1,052,400 to 1,243,400
# 12                              300 to 4,661
# 16                     2,840,000 to3,394,369
# 18                                    117466
# 23                    2,198,420 to 2,800,720
#
#                    Deaths as % of population  \
#    Allies and co-belligerents of World War I
# 6                               1.9% to 2.2%
# 9                               4.3% to 4.4%
# 11                                3% to 3.5%
# 12                                  0% to 0%
# 16                              1.6% to 1.9%
# 18                                      0.1%
# 23                              3.4% to 4.3%
#
#                             Military wounded
#    Allies and co-belligerents of World War I
# 6                                1,675,000s1
# 9                              4,266,000[33]
# 11                               947,000[33]
# 12                                   907[33]
# 16             3,749,000[48] to4,950,000[33]
# 18                               204,002[53]
# 23                             4,215,662[64]

# %%
WW1.drop(['Military wounded'], axis=1, inplace=True)

# %%
WW1.drop(['Combat deaths and missing in action (included in total military deaths)'], axis=1, inplace=True)
                                                 
WW1.drop(['Increase in civilian deaths (malnutrition and disease excluding Influenza pandemic)'], axis=1, inplace=True)

# %%
WW1.head()

# %%
WW1.drop_duplicates()

# %%
import requests
from bs4 import BeautifulSoup

url = "https://en.wikipedia.org/wiki/World_War_I_casualties"
page = requests.get(url)

soup = BeautifulSoup(page.content, 'html.parser')
indiatable=soup.find('table',{'class':"wikitable"})

import pandas as pd

# %%
listings = soup.find_all("li", class_="td")
for listing in listings:
        print("tables")

# %%
df=pd.read_html(str(indiatable))

# %%
world_war = df[0]

# %%
type(world_war.columns)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
world_war.columns = world_war.columns.droplevel(level=1)

# %%
world_war.columns
# Out:
# Index(['Nation', 'Population (millions)',
#        'Combat deaths and missing in action (included in total military deaths)',
#        'Total military deaths (from all causes)',
#        'Civilian deaths (military action and crimes against humanity)',
#        'Increase in civilian deaths (malnutrition and disease excluding Influenza pandemic)',
#        'Total deaths', 'Deaths as % of population', 'Military wounded'],
#       dtype='object')

# %%
world_war.columns[-2]
# Out:
# 'Deaths as\xa0% of population'

# %%
world_war.iloc[:, -2].head()
# Out:
# 0    1.2% to 1.2%
# 1    0.8% to 0.9%
# 2        0% to 0%
# 3    1.5% to 1.6%
# 4    0.6% to 0.8%
# Name: Deaths as % of population, dtype: object

# %%
world_war = world_war.drop(labels=[0,1,2,3,4,5,7,8,10,13,14,15,17,19,20,21,22,24,25,26,27,28,29,30,31,32], axis=0)

# %%
world_war.iloc[:,-2].values
# Out:
# array(['1.9% to 2.2%', '4.3% to 4.4%', '3% to 3.5%', '0% to 0%',
#        '1.6% to 1.9%', '0.1%', '3.4% to 4.3%'], dtype=object)

# %%
world_war.iloc[:,-2].str.split("%").str[0]
# Out:
# 6     1.9
# 9     4.3
# 11      3
# 12      0
# 16    1.6
# 18    0.1
# 23    3.4
# Name: Deaths as % of population, dtype: object

# %%
filtered_deaths_percent = world_war.iloc[:,-2].str.split("%").str[0].values

# %%
filtered_deaths_percent
# Out:
# array(['1.9', '4.3', '3', '0', '1.6', '0.1', '3.4'], dtype=object)

# %%
world_war_updated = world_war

# %%
world_war_updated.iloc[:,-2] = filtered_deaths_percent

# %%
world_war_updated
# Out:
#                             Nation Population (millions)  \
# 6   United Kingdom(and Colonies) s                  45.4
# 9                         France e                  39.6
# 11                         Italy h                  35.6
# 12                         Japan i                  53.6
# 16                        Russia p                 175.1
# 18                 United States t                  92.0
# 23                       Germany w                  64.9
#
#    Combat deaths and missing in action (included in total military deaths)  \
# 6                                           744,000s1
# 9                                   1,150,000[34][35]
# 11                                        460,000[29]
# 12                                            300[33]
# 16                       775,369 to 1,700,000[33][20]
# 18                                         53,402[52]
# 23                              1,800,000[33][62][63]
#
#    Total military deaths (from all causes)  \
# 6                              887,858[11]
# 9            1,357,000[20]to 1,397,800[36]
# 11              460,000[29] to 651,000[41]
# 12                    300[33] to 4,661[44]
# 16           1,700,000[33] to2,254,369[48]
# 18                         116,708[53][54]
# 23                       2,037,000[64][65]
#
#    Civilian deaths (military action and crimes against humanity)  \
# 6                                      16,829[21][27]
# 9                                  40,000[18][37][38]
# 11                                          3,400[42]
# 12                                                NaN
# 16                                        410,000[49]
# 18                                            757[55]
# 23                                            720[66]
#
#    Increase in civilian deaths (malnutrition and disease excluding Influenza pandemic)  \
# 6                                         107,000[28]
# 9                                         300,000[32]
# 11                                        589,000[43]
# 12                                                NaN
# 16                                        730,000[49]
# 18                                                NaN
# 23                     424,000[67] to 763,000[68][69]
#
#               Total deaths Deaths as % of population  \
# 6     867,829 to 1,011,687                       1.9
# 9    1,697,000to 1,737,800                       4.3
# 11  1,052,400 to 1,243,400                         3
# 12            300 to 4,661                         0
# 16   2,840,000 to3,394,369                       1.6
# 18                  117466                       0.1
# 23  2,198,420 to 2,800,720                       3.4
#
#                  Military wounded
# 6                     1,675,000s1
# 9                   4,266,000[33]
# 11                    947,000[33]
# 12                        907[33]
# 16  3,749,000[48] to4,950,000[33]
# 18                    204,002[53]
# 23                  4,215,662[64]

# %%
convert_col_numeric = pd.to_numeric(world_war_updated.iloc[:,-2])

# %%
world_war_updated.iloc[:,-2] = convert_col_numeric

# %%
world_war_updated
# Out:
#                             Nation Population (millions)  \
# 6   United Kingdom(and Colonies) s                  45.4
# 9                         France e                  39.6
# 11                         Italy h                  35.6
# 12                         Japan i                  53.6
# 16                        Russia p                 175.1
# 18                 United States t                  92.0
# 23                       Germany w                  64.9
#
#    Combat deaths and missing in action (included in total military deaths)  \
# 6                                           744,000s1
# 9                                   1,150,000[34][35]
# 11                                        460,000[29]
# 12                                            300[33]
# 16                       775,369 to 1,700,000[33][20]
# 18                                         53,402[52]
# 23                              1,800,000[33][62][63]
#
#    Total military deaths (from all causes)  \
# 6                              887,858[11]
# 9            1,357,000[20]to 1,397,800[36]
# 11              460,000[29] to 651,000[41]
# 12                    300[33] to 4,661[44]
# 16           1,700,000[33] to2,254,369[48]
# 18                         116,708[53][54]
# 23                       2,037,000[64][65]
#
#    Civilian deaths (military action and crimes against humanity)  \
# 6                                      16,829[21][27]
# 9                                  40,000[18][37][38]
# 11                                          3,400[42]
# 12                                                NaN
# 16                                        410,000[49]
# 18                                            757[55]
# 23                                            720[66]
#
#    Increase in civilian deaths (malnutrition and disease excluding Influenza pandemic)  \
# 6                                         107,000[28]
# 9                                         300,000[32]
# 11                                        589,000[43]
# 12                                                NaN
# 16                                        730,000[49]
# 18                                                NaN
# 23                     424,000[67] to 763,000[68][69]
#
#               Total deaths  Deaths as % of population  \
# 6     867,829 to 1,011,687                        1.9
# 9    1,697,000to 1,737,800                        4.3
# 11  1,052,400 to 1,243,400                        3.0
# 12            300 to 4,661                        0.0
# 16   2,840,000 to3,394,369                        1.6
# 18                  117466                        0.1
# 23  2,198,420 to 2,800,720                        3.4
#
#                  Military wounded
# 6                     1,675,000s1
# 9                   4,266,000[33]
# 11                    947,000[33]
# 12                        907[33]
# 16  3,749,000[48] to4,950,000[33]
# 18                    204,002[53]
# 23                  4,215,662[64]

# %%
world_war_updated["Nation"].str.split().str[:-1]
# Out:
# 6     [United, Kingdom(and, Colonies)]
# 9                             [France]
# 11                             [Italy]
# 12                             [Japan]
# 16                            [Russia]
# 18                    [United, States]
# 23                           [Germany]
# Name: Nation, dtype: object

# %%
nations_updated = world_war_updated["Nation"].str.split().str[:-1].str.join(" ").str.split("(").str[0]

# %%
nations_updated
# Out:
# 6     United Kingdom
# 9             France
# 11             Italy
# 12             Japan
# 16            Russia
# 18     United States
# 23           Germany
# Name: Nation, dtype: object

# %%
world_war_updated["Nation"] = nations_updated

# %%
world_war_updated
# Out:
#             Nation Population (millions)  \
# 6   United Kingdom                  45.4
# 9           France                  39.6
# 11           Italy                  35.6
# 12           Japan                  53.6
# 16          Russia                 175.1
# 18   United States                  92.0
# 23         Germany                  64.9
#
#    Combat deaths and missing in action (included in total military deaths)  \
# 6                                           744,000s1
# 9                                   1,150,000[34][35]
# 11                                        460,000[29]
# 12                                            300[33]
# 16                       775,369 to 1,700,000[33][20]
# 18                                         53,402[52]
# 23                              1,800,000[33][62][63]
#
#    Total military deaths (from all causes)  \
# 6                              887,858[11]
# 9            1,357,000[20]to 1,397,800[36]
# 11              460,000[29] to 651,000[41]
# 12                    300[33] to 4,661[44]
# 16           1,700,000[33] to2,254,369[48]
# 18                         116,708[53][54]
# 23                       2,037,000[64][65]
#
#    Civilian deaths (military action and crimes against humanity)  \
# 6                                      16,829[21][27]
# 9                                  40,000[18][37][38]
# 11                                          3,400[42]
# 12                                                NaN
# 16                                        410,000[49]
# 18                                            757[55]
# 23                                            720[66]
#
#    Increase in civilian deaths (malnutrition and disease excluding Influenza pandemic)  \
# 6                                         107,000[28]
# 9                                         300,000[32]
# 11                                        589,000[43]
# 12                                                NaN
# 16                                        730,000[49]
# 18                                                NaN
# 23                     424,000[67] to 763,000[68][69]
#
#               Total deaths  Deaths as % of population  \
# 6     867,829 to 1,011,687                        1.9
# 9    1,697,000to 1,737,800                        4.3
# 11  1,052,400 to 1,243,400                        3.0
# 12            300 to 4,661                        0.0
# 16   2,840,000 to3,394,369                        1.6
# 18                  117466                        0.1
# 23  2,198,420 to 2,800,720                        3.4
#
#                  Military wounded
# 6                     1,675,000s1
# 9                   4,266,000[33]
# 11                    947,000[33]
# 12                        907[33]
# 16  3,749,000[48] to4,950,000[33]
# 18                    204,002[53]
# 23                  4,215,662[64]

# %%
WW2
# Out:
#            Country  Total pop 19391939  Militarydeaths Civilian deaths  \
# 10           Japan            71380000         2300000          800000
# 4           France            41680000          210000          390000
# 15    Soviet Union           188793000        11400000        10000000
# 9            Italy            44394000          341000          153200
# 5          Germany            69300000         5318000         3000000
# 20  United Kingdom            47760000          383700           67200
# 0        Australia             6968000           39700             700
# 8            India           377800000           87000             NaN
# 21   United States           131028000          407300           12100
# 14    South Africa            10160000           11900             NaN
#
#    Totaldeaths  % of Population Militarywounded
# 10     3100000            3.920          326000
# 4       600000            1.440          390000
# 15    27000000            1.150             NaN
# 9       492400            1.135          320000
# 5      7400000            1.000         7300000
# 20      450900            0.940          376239
# 0        40400            0.580           39803
# 8      3087000            0.580           64354
# 21      419400            0.320          671801
# 14       11900            0.120           14363

# %%
Tab = WW2.replace('Soviet Union', 'Russia')

# %%
WW2 = Tab

# %%
WW2
# Out:
#            Country  Total pop 19391939  Militarydeaths Civilian deaths  \
# 10           Japan          71380000.0       2300000.0          800000
# 4           France          41680000.0        210000.0          390000
# 15          Russia         188793000.0      11400000.0        10000000
# 9            Italy          44394000.0        341000.0          153200
# 5          Germany          69300000.0       5318000.0         3000000
# 20  United Kingdom          47760000.0        383700.0           67200
# 0        Australia           6968000.0         39700.0             700
# 8            India         377800000.0         87000.0             NaN
# 21   United States         131028000.0        407300.0           12100
# 14    South Africa          10160000.0         11900.0             NaN
# 2           Russia                 NaN             NaN             NaN
#
#    Totaldeaths  % of Population Militarywounded
# 10     3100000            3.920          326000
# 4       600000            1.440          390000
# 15    27000000            1.150             NaN
# 9       492400            1.135          320000
# 5      7400000            1.000         7300000
# 20      450900            0.940          376239
# 0        40400            0.580           39803
# 8      3087000            0.580           64354
# 21      419400            0.320          671801
# 14       11900            0.120           14363
# 2          NaN              NaN             NaN

# %%
Twoworldwars = pd.merge(world_war_updated, WW2, left_on = 'Nation', right_on = 'Country')

# %%
Twoworldwars
# Out:
#            Nation Population (millions)  \
# 0  United Kingdom                  45.4
# 1          France                  39.6
# 2           Italy                  35.6
# 3           Japan                  53.6
# 4          Russia                 175.1
# 5          Russia                 175.1
# 6   United States                  92.0
# 7         Germany                  64.9
#
#   Combat deaths and missing in action (included in total military deaths)  \
# 0                                          744,000s1
# 1                                  1,150,000[34][35]
# 2                                        460,000[29]
# 3                                            300[33]
# 4                       775,369 to 1,700,000[33][20]
# 5                       775,369 to 1,700,000[33][20]
# 6                                         53,402[52]
# 7                              1,800,000[33][62][63]
#
#   Total military deaths (from all causes)  \
# 0                             887,858[11]
# 1           1,357,000[20]to 1,397,800[36]
# 2              460,000[29] to 651,000[41]
# 3                    300[33] to 4,661[44]
# 4           1,700,000[33] to2,254,369[48]
# 5           1,700,000[33] to2,254,369[48]
# 6                         116,708[53][54]
# 7                       2,037,000[64][65]
#
#   Civilian deaths (military action and crimes against humanity)  \
# 0                                     16,829[21][27]
# 1                                 40,000[18][37][38]
# 2                                          3,400[42]
# 3                                                NaN
# 4                                        410,000[49]
# 5                                        410,000[49]
# 6                                            757[55]
# 7                                            720[66]
#
#   Increase in civilian deaths (malnutrition and disease excluding Influenza pandemic)  \
# 0                                        107,000[28]
# 1                                        300,000[32]
# 2                                        589,000[43]
# 3                                                NaN
# 4                                        730,000[49]
# 5                                        730,000[49]
# 6                                                NaN
# 7                     424,000[67] to 763,000[68][69]
#
#              Total deaths  Deaths as % of population  \
# 0    867,829 to 1,011,687                        1.9
# 1   1,697,000to 1,737,800                        4.3
# 2  1,052,400 to 1,243,400                        3.0
# 3            300 to 4,661                        0.0
# 4   2,840,000 to3,394,369                        1.6
# 5   2,840,000 to3,394,369                        1.6
# 6                  117466                        0.1
# 7  2,198,420 to 2,800,720                        3.4
#
#                 Military wounded         Country  Total pop 19391939  \
# 0                    1,675,000s1  United Kingdom          47760000.0
# 1                  4,266,000[33]          France          41680000.0
# 2                    947,000[33]           Italy          44394000.0
# 3                        907[33]           Japan          71380000.0
# 4  3,749,000[48] to4,950,000[33]          Russia         188793000.0
# 5  3,749,000[48] to4,950,000[33]          Russia                 NaN
# 6                    204,002[53]   United States         131028000.0
# 7                  4,215,662[64]         Germany          69300000.0
#
#    Militarydeaths Civilian deaths Totaldeaths  % of Population Militarywounded
# 0        383700.0           67200      450900            0.940          376239
# 1        210000.0          390000      600000            1.440          390000
# 2        341000.0          153200      492400            1.135          320000
# 3       2300000.0          800000     3100000            3.920          326000
# 4      11400000.0        10000000    27000000            1.150             NaN
# 5             NaN             NaN         NaN              NaN             NaN
# 6        407300.0           12100      419400            0.320          671801
# 7       5318000.0         3000000     7400000            1.000         7300000

# %%
Table1 = Twoworldwars.iloc[:, [0,6,7,9,13,14]]

# %%
Table1
# Out:
#            Nation            Total deaths  Deaths as % of population  \
# 0  United Kingdom    867,829 to 1,011,687                        1.9
# 1          France   1,697,000to 1,737,800                        4.3
# 2           Italy  1,052,400 to 1,243,400                        3.0
# 3           Japan            300 to 4,661                        0.0
# 4          Russia   2,840,000 to3,394,369                        1.6
# 5          Russia   2,840,000 to3,394,369                        1.6
# 6   United States                  117466                        0.1
# 7         Germany  2,198,420 to 2,800,720                        3.4
#
#           Country Totaldeaths  % of Population
# 0  United Kingdom      450900            0.940
# 1          France      600000            1.440
# 2           Italy      492400            1.135
# 3           Japan     3100000            3.920
# 4          Russia    27000000            1.150
# 5          Russia         NaN              NaN
# 6   United States      419400            0.320
# 7         Germany     7400000            1.000

# %%
Table1.drop_duplicates(subset=['Country', 'Nation'])
# Out:
#            Nation            Total deaths  Deaths as % of population  \
# 0  United Kingdom    867,829 to 1,011,687                        1.9
# 1          France   1,697,000to 1,737,800                        4.3
# 2           Italy  1,052,400 to 1,243,400                        3.0
# 3           Japan            300 to 4,661                        0.0
# 4          Russia   2,840,000 to3,394,369                        1.6
# 6   United States                  117466                        0.1
# 7         Germany  2,198,420 to 2,800,720                        3.4
#
#           Country Totaldeaths  % of Population
# 0  United Kingdom      450900            0.940
# 1          France      600000            1.440
# 2           Italy      492400            1.135
# 3           Japan     3100000            3.920
# 4          Russia    27000000            1.150
# 6   United States      419400            0.320
# 7         Germany     7400000            1.000

# %%
Table1.rename(columns={'Total deaths':'Total_WW1'}, inplace = True)
# Out:
# C:\Users\cgleeson\AppData\Local\Temp\ipykernel_16424\4001061581.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Table1.rename(columns={'Total deaths':'Total_WW1'}, inplace = True)

# %%
Table1.rename(columns={'Deaths as % of population':'%1', '% of Population':'%2'}, inplace = True)
# Out:
# C:\Users\cgleeson\AppData\Local\Temp\ipykernel_16424\2604341306.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Table1.rename(columns={'Deaths as % of population':'%1', '% of Population':'%2'}, inplace = True)

# %%
Table1
# Out:
#           Country               Total_WW1  Deaths as % of population  \
# 0  United Kingdom    867,829 to 1,011,687                        1.9
# 1          France   1,697,000to 1,737,800                        4.3
# 2           Italy  1,052,400 to 1,243,400                        3.0
# 3           Japan            300 to 4,661                        0.0
# 4          Russia   2,840,000 to3,394,369                        1.6
# 5          Russia   2,840,000 to3,394,369                        1.6
# 6   United States                  117466                        0.1
# 7         Germany  2,198,420 to 2,800,720                        3.4
#
#           Country Total_WW2  %_WW2
# 0  United Kingdom    450900  0.940
# 1          France    600000  1.440
# 2           Italy    492400  1.135
# 3           Japan   3100000  3.920
# 4          Russia  27000000  1.150
# 5          Russia       NaN    NaN
# 6   United States    419400  0.320
# 7         Germany   7400000  1.000

# %%
Table2 = Table1.drop_duplicates(subset=['Country'])

# %%
Table2
# Out:
#           Country               Total_WW1  Deaths as % of population  \
# 0  United Kingdom    867,829 to 1,011,687                        1.9
# 1          France   1,697,000to 1,737,800                        4.3
# 2           Italy  1,052,400 to 1,243,400                        3.0
# 3           Japan            300 to 4,661                        0.0
# 4          Russia   2,840,000 to3,394,369                        1.6
# 6   United States                  117466                        0.1
# 7         Germany  2,198,420 to 2,800,720                        3.4
#
#           Country Total_WW2  %_WW2
# 0  United Kingdom    450900  0.940
# 1          France    600000  1.440
# 2           Italy    492400  1.135
# 3           Japan   3100000  3.920
# 4          Russia  27000000  1.150
# 6   United States    419400  0.320
# 7         Germany   7400000  1.000

# %%
Table2.rename(columns={'Deaths as\xa0% of population':'%_WW1'}, inplace = True)
# Out:
# C:\Users\cgleeson\AppData\Local\Temp\ipykernel_16424\239907985.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Table2.rename(columns={'Deaths as\xa0% of population':'%_WW1'}, inplace = True)

# %%
Table2
# Out:
#           Country               Total_WW1  %_WW1         Country Total_WW2  \
# 0  United Kingdom    867,829 to 1,011,687    1.9  United Kingdom    450900
# 1          France   1,697,000to 1,737,800    4.3          France    600000
# 2           Italy  1,052,400 to 1,243,400    3.0           Italy    492400
# 3           Japan            300 to 4,661    0.0           Japan   3100000
# 4          Russia   2,840,000 to3,394,369    1.6          Russia  27000000
# 6   United States                  117466    0.1   United States    419400
# 7         Germany  2,198,420 to 2,800,720    3.4         Germany   7400000
#
#    %_WW2
# 0  0.940
# 1  1.440
# 2  1.135
# 3  3.920
# 4  1.150
# 6  0.320
# 7  1.000

# %%
Table2.describe()
# Out:
#           %_WW1     %_WW2
# count  7.000000  7.000000
# mean   2.042857  1.415000
# std    1.633868  1.156226
# min    0.000000  0.320000
# 25%    0.850000  0.970000
# 50%    1.900000  1.135000
# 75%    3.200000  1.295000
# max    4.300000  3.920000

# %%
for ind in Table2.index:
    print(Table2['%_WW1'][ind], Table2['Total_WW1'][ind])
# Out:
# 1.9 867,829 to 1,011,687
# 4.3 1,697,000to 1,737,800
# 3.0 1,052,400 to 1,243,400
# 0.0 300 to 4,661
# 1.6 2,840,000 to3,394,369
# 0.1 117466
# 3.4 2,198,420 to 2,800,720

# %%
for ind in Table2.index:
    print(Table2['%_WW2'][ind], Table2['Total_WW2'][ind])
# Out:
# 0.94 450900
# 1.44 600000
# 1.135 492400
# 3.92 3100000
# 1.15 27000000
# 0.32 419400
# 1.0 7400000

# %%
Table2.groupby(['%_WW1', '%_WW2']).size()
# Out:
# %_WW1  %_WW2
# 0.0    3.920    1
# 0.1    0.320    1
# 1.6    1.150    1
# 1.9    0.940    1
# 3.0    1.135    1
# 3.4    1.000    1
# 4.3    1.440    1
# dtype: int64
