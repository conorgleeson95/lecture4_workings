# %%
import pandas as pd
df = pd.read_csv("ww2_dataset2.csv")

# %%
df.head()
# Out:
#      Country Total population as of 1/1/1939 Militarydeaths from all causes  \
# 0    Albania                       1,073,000                         30,000
# 1  Australia                       6,968,000                         39,700
# 2    Austria                       6,653,000          Included with Germany
# 3    Belgium                       8,387,000                         12,000
# 4     Brazil                      40,289,000                          1,000
#
#   Civilian deaths due tomilitary activity and crimes against humanity  \
# 0                                                NaN
# 1                                                700
# 2                              Included with Germany
# 3                                             76,000
# 4                                              1,000
#
#   Totaldeaths Deaths as % of1939 population  \
# 0       30000                           2.8
# 1       40400                          0.58
# ...

# %%
df['Country']
# Out:
# 0            Albania
# 1          Australia
# 2            Austria
# 3            Belgium
# 4             Brazil
#            ...
# 56          Thailand
# 57            Turkey
# 58    United Kingdom
# 59     United States
# 60        Yugoslavia
# Name: Country, Length: 61, dtype: object

# %%
df[['Country', 'Total population as of 1/1/1939']]
# Out:
#            Country Total population as of 1/1/1939
# 0          Albania                       1,073,000
# 1        Australia                       6,968,000
# 2          Austria                       6,653,000
# 3          Belgium                       8,387,000
# 4           Brazil                      40,289,000
# ..             ...                             ...
# 56        Thailand                      15,023,000
# 57          Turkey                      17,370,000
# 58  United Kingdom                      47,760,000
# 59   United States                     131,028,000
# 60      Yugoslavia                      15,490,000
#
# [61 rows x 2 columns]

# %%
df[['Country', 'Totaldeaths']]
# Out:
#            Country             Totaldeaths
# 0          Albania                   30000
# 1        Australia                   40400
# 2          Austria                     NaN
# 3          Belgium                   88000
# 4           Brazil                    2000
# ..             ...                     ...
# 56        Thailand                    7600
# 57          Turkey                     200
# 58  United Kingdom                  450900
# 59   United States                  419400
# 60      Yugoslavia  1,027,000 to 1,700,000
#
# [61 rows x 2 columns]

# %%
import seaborn as sns
Casualties = sns.load_dataset("ww2_dataset2.csv")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [2], in <cell line: 2>()
#       1 import seaborn as sns
# ----> 2 Casualties = sns.load_dataset("ww2_dataset2.csv")
#
# File ~\Anaconda3\lib\site-packages\seaborn\utils.py:595, in load_dataset(name, cache, data_home, **kws)
#     593 if not os.path.exists(cache_path):
#     594     if name not in get_dataset_names():
# --> 595         raise ValueError(f"'{name}' is not one of the example datasets.")
#     596     urlretrieve(url, cache_path)
#     597 full_path = cache_path
#
# ValueError: 'ww2_dataset2.csv' is not one of the example datasets.

# %%
ww2_dataset2.csv.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 ww2_dataset2.csv.info()
#
# NameError: name 'ww2_dataset2' is not defined

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
df = pd.read_csv("ww2_dataset2.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 8 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Country                                                              61 non-null     object
#  1   Total population as of 1/1/1939                                      61 non-null     object
#  2   Militarydeaths from all causes                                       49 non-null     object
#  3   Civilian deaths due tomilitary activity and crimes against humanity  49 non-null     object
#  4   Totaldeaths                                                          58 non-null     object
#  5   Deaths as % of1939 population                                        59 non-null     object
#  6   Average Deaths as % of1939 population                                59 non-null     object
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=61, step=1)

# %%
df.describe()
# Out:
#         Country Total population as of 1/1/1939  \
# count        61                              61
# unique       61                              61
# top     Albania                       1,073,000
# freq          1                               1
#
#        Militarydeaths from all causes  \
# count                              49
# unique                             46
# top                            30,000
# freq                                2
#
#        Civilian deaths due tomilitary activity and crimes against humanity  \
# count                                                  49
# unique                                                 43
# top                                                   100
# freq                                                    5
#
#        Totaldeaths Deaths as % of1939 population  \
# count           58                            59
# unique          53                            50
# top            100                             0
# ...

# %%
df.dtypes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 df.dtypes()
#
# TypeError: 'Series' object is not callable

# %%
df['Militarywounded']
# Out:
# 0                       NaN
# 1                    39,803
# 2     Included with Germany
# 3                    55,513
# 4                     4,222
#               ...
# 56                      NaN
# 57                      NaN
# 58                  376,239
# 59                  671,801
# 60                  425,000
# Name: Militarywounded, Length: 61, dtype: object

# %%
df[['Country', 'Militarywounded']]
# Out:
#            Country        Militarywounded
# 0          Albania                    NaN
# 1        Australia                 39,803
# 2          Austria  Included with Germany
# 3          Belgium                 55,513
# 4           Brazil                  4,222
# ..             ...                    ...
# 56        Thailand                    NaN
# 57          Turkey                    NaN
# 58  United Kingdom                376,239
# 59   United States                671,801
# 60      Yugoslavia                425,000
#
# [61 rows x 2 columns]

# %%
df[['Country', 'Militarywounded', 'Totaldeaths']]
# Out:
#            Country        Militarywounded             Totaldeaths
# 0          Albania                    NaN                   30000
# 1        Australia                 39,803                   40400
# 2          Austria  Included with Germany                     NaN
# 3          Belgium                 55,513                   88000
# 4           Brazil                  4,222                    2000
# ..             ...                    ...                     ...
# 56        Thailand                    NaN                    7600
# 57          Turkey                    NaN                     200
# 58  United Kingdom                376,239                  450900
# 59   United States                671,801                  419400
# 60      Yugoslavia                425,000  1,027,000 to 1,700,000
#
# [61 rows x 3 columns]

# %%
df[0:5][['Country', 'Militarywounded', 'Totaldeaths']]
# Out:
#      Country        Militarywounded Totaldeaths
# 0    Albania                    NaN       30000
# 1  Australia                 39,803       40400
# 2    Austria  Included with Germany         NaN
# 3    Belgium                 55,513       88000
# 4     Brazil                  4,222        2000

# %%
df.iloc[[1, 10, 20, 30, 40, 50, 60], [0,1,2,3,4,5]]
# Out:
#            Country Total population as of 1/1/1939  \
# 1        Australia                       6,968,000
# 10  Czechoslovakia                      14,612,000
# 20          Greece                       7,222,000
# 30           Korea                      24,326,000
# 40     Netherlands                       8,729,000
# 50    South Africa                      10,160,000
# 60      Yugoslavia                      15,490,000
#
#      Militarydeaths from all causes  \
# 1                            39,700
# 10                 35,000 to 46,000
# 20                           35,100
# 30  Included with Japanese military
# 40                            6,700
# 50                           11,900
# 60               300,000 to 446,000
#
#    Civilian deaths due tomilitary activity and crimes against humanity  \
# 1                                                 700
# 10                                  294,000 to320,000
# 20                                            171,800
# ...

# %%
df[df['Totaldeaths'] > 100000]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 df[df['Totaldeaths'] > 100000]
#
# File ~\Anaconda3\lib\site-packages\pandas\core\ops\common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File ~\Anaconda3\lib\site-packages\pandas\core\arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File ~\Anaconda3\lib\site-packages\pandas\core\series.py:5623, in Series._cmp_method(self, other, op)
#    5620 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    5622 with np.errstate(all="ignore"):
# ...
