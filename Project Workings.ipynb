# %%
import pandas as pd
df = pd.read_csv("ww2_dataset2.csv")

# %%
df.head()
# Out:
#      Country Total population as of 1/1/1939 Militarydeaths from all causes  \
# 0    Albania                       1,073,000                         30,000
# 1  Australia                       6,968,000                         39,700
# 2    Austria                       6,653,000          Included with Germany
# 3    Belgium                       8,387,000                         12,000
# 4     Brazil                      40,289,000                          1,000
#
#   Civilian deaths due tomilitary activity and crimes against humanity  \
# 0                                                NaN
# 1                                                700
# 2                              Included with Germany
# 3                                             76,000
# 4                                              1,000
#
#   Totaldeaths Deaths as % of1939 population  \
# 0       30000                           2.8
# 1       40400                          0.58
# ...

# %%
df['Country']
# Out:
# 0            Albania
# 1          Australia
# 2            Austria
# 3            Belgium
# 4             Brazil
#            ...
# 56          Thailand
# 57            Turkey
# 58    United Kingdom
# 59     United States
# 60        Yugoslavia
# Name: Country, Length: 61, dtype: object

# %%
df[['Country', 'Total population as of 1/1/1939']]
# Out:
#            Country Total population as of 1/1/1939
# 0          Albania                       1,073,000
# 1        Australia                       6,968,000
# 2          Austria                       6,653,000
# 3          Belgium                       8,387,000
# 4           Brazil                      40,289,000
# ..             ...                             ...
# 56        Thailand                      15,023,000
# 57          Turkey                      17,370,000
# 58  United Kingdom                      47,760,000
# 59   United States                     131,028,000
# 60      Yugoslavia                      15,490,000
#
# [61 rows x 2 columns]

# %%
df[['Country', 'Totaldeaths']]
# Out:
#            Country             Totaldeaths
# 0          Albania                   30000
# 1        Australia                   40400
# 2          Austria                     NaN
# 3          Belgium                   88000
# 4           Brazil                    2000
# ..             ...                     ...
# 56        Thailand                    7600
# 57          Turkey                     200
# 58  United Kingdom                  450900
# 59   United States                  419400
# 60      Yugoslavia  1,027,000 to 1,700,000
#
# [61 rows x 2 columns]
